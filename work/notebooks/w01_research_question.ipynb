# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# 1. **Lane** --> Freestyle.
#
# 2. **Question** --> What characteristics distinguish pages that receive AI-generated referrals from similar pages that do not, and can those characteristics prioritize future optimization opportunities?
#
# 3. **Why this Question and Lane** --> As AI assistants increasingly become discovery channels, websites need ways to understand AI-generated traffic. This exploratory project investigates what differentiates pages that receive AI referrals from comparable pages that do not. Because positive examples remain relatively sparse, the focus is on exploratory data analysis, ranking heuristics, and hypothesis generation rather than deploying a production prediction model.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# 1. This project aim to improve content managers, content developer and SEO Experts understanding of how to make their contents visible to AI systems for referrals.
#
# 2. SEO managers, content managers and anyone working on improving website visibilities
#
# 3. Wrong recommendation means AI referral is impossible and this could translate to traffic loss, and potential sales loss

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
from google.colab import userdata
api_key=userdata.get('hf_key')

# %%
from datasets import load_dataset
ds = load_dataset("FlyRank/internship-warehouse", "fact_content_daily_performance", streaming=True, split="train", token=api_key)
# Out:
# Resolving data files:   0%|          | 0/18 [00:00<?, ?it/s]

# %%
for i, example in enumerate(ds):
    if i >= 25:
        break
    print(example)
# Out:
# {'report_date': datetime.date(2025, 1, 27), 'client_hash_id': 'client_9958f0a7ae1df715', 'content_hash_id': 'content_3b70a18ea133b2bb', 'client_has_gsc': True, 'client_has_ga4': True, 'gsc_data_available': True, 'ga4_data_available': False, 'gsc_impressions': 30, 'gsc_clicks': 0, 'gsc_sum_position': 115, 'gsc_avg_position': 3.8333333333333335, 'ga4_pageviews': 0, 'ga4_sessions': 0, 'ga4_users': 0, 'ga4_engaged_sessions': 0, 'ga4_total_engagement_sec': 0, 'sessions_organic': 0, 'sessions_direct': 0, 'sessions_referral': 0, 'sessions_social': 0, 'sessions_paid': 0, 'sessions_ai': 0, 'ai_chatgpt': 0, 'ai_perplexity': 0, 'ai_gemini': 0, 'ai_copilot': 0, 'ai_claude': 0, 'ai_meta': 0, 'ai_other': 0, 'scroll_events': 0}
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What this project can claim
# - I can only claim observed patterns, directional evidence, decision supports i.e. just patterns observed in during the EDA.
#
# What this project cannot claim
# - Correlation doesn't prove causation.
# - I cannot predict the behavior of the AI system with certainty.
# - I can only analyze the observable outcomes and not the internal logic of the AI search or retrieval system.
# - My observation is just to identify and recommend opportunities with higher expected potential, not guaranteed results.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
